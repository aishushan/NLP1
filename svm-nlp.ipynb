# %%
import pandas as pd
import numpy as np 
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
df=pd.read_csv("C:/Users/Aiswarya/Downloads/final_alert_dataset.csv")
df
# Out:
#     Incident ID        Date      Time                                Title  \
# 0       IN31001  25/06/2023  08:55:00                      Application Bug
# 1        IN1001  28/06/2022  03:22:55  Application Upgrade Incompatibility
# 2        IN2001  26/12/2020  05:50:32               Database Query Timeout
# 3        IN3001  01/12/2023  14:10:00              Software License Expiry
# 4        IN4001  03/03/2021  13:35:32           Application Freeze or Hang
# ..          ...         ...       ...                                  ...
# 853      IN3001  23/09/2023  13:30:00                      Data Corruption
# 854      IN4001  04/06/2021  10:42:03              Server Room Power Surge
# 855      IN5001  09/07/2021  07:20:40          Data Center Cooling Failure
# 856      IN6001  22/10/2021  21:08:04          Social Engineering Incident
# 857      IN7001  17/06/2022  06:39:58             Slow Network Performance
#
#                                            Description              Category  \
# 0    Users are experiencing unexpected errors in th...           Application
# 1    An application upgrade introduces incompatibil...     Application Issue
# 2    Database queries are timing out causing delays...     Performance Issue
# 3                    The software license has expired.        Infrastructure
# 4    An application freezes or hangs becoming unres...           Performance
# ..                                                 ...                   ...
# 853    Data integrity issues detected in the database.                  Data
# 854  There is a power surge in the server room pote...  Infrastructure Issue
# 855  The cooling system in the data center has fail...  Infrastructure Issue
# 856  An employee falls victim to a social engineeri...              Security
# 857  The network is experiencing slow performance c...               Network
#
#      Priority       Status     Location      Department Duration  \
# 0      Medium         Open       Office    Applications        -
# 1        High     Resolved  Server Room    Applications       60
# 2      Medium     Resolved  Data Center              IT       45
# 3         Low     Resolved       Office              IT       10
# 4        High     Resolved       Office              IT       15
# ..        ...          ...          ...             ...      ...
# 853      High  In Progress       Office              IT        -
# 854  Critical     Resolved  Server Room  Infrastructure       45
# 855      High     Resolved  Data Center  Infrastructure       90
# 856    Medium     Resolved       Office              IT       15
# 857      High     Resolved  Data Center              IT       45
#
#     Response Time Resolution Time           Class
# 0               -               -     Application
# 1              20              40     Application
# 2              15              30     Performance
# 3               5               5  Infrastructure
# 4               5              10     Performance
# ..            ...             ...             ...
# 853             -               -            Data
# 854            15              30  Infrastructure
# 855            30              60  Infrastructure
# 856             5              10        Security
# 857            15              30         Network
#
# [858 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 858 entries, 0 to 857
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Incident ID      858 non-null    object
#  1   Date             858 non-null    object
#  2   Time             858 non-null    object
#  3   Title            858 non-null    object
#  4   Description      858 non-null    object
#  5   Category         858 non-null    object
#  6   Priority         858 non-null    object
#  7   Status           858 non-null    object
#  8   Location         858 non-null    object
#  9   Department       858 non-null    object
#  10  Duration         858 non-null    object
#  11  Response Time    858 non-null    object
#  12  Resolution Time  858 non-null    object
#  13  Class            858 non-null    object
# dtypes: object(14)
# memory usage: 94.0+ KB

# %%
count=df['Class'].value_counts()
count
# Out:
# Application       176
# Infrastructure    131
# Data              102
# Network           100
# Performance        98
# Security           94
# Hardware           90
# Configuration      67
# Name: Class, dtype: int64

# %%
df['Title']=df['Title'].str.lower()
df['Title']
# Out:
# 0                          application bug
# 1      application upgrade incompatibility
# 2                   database query timeout
# 3                  software license expiry
# 4               application freeze or hang
#                       ...
# 853                        data corruption
# 854                server room power surge
# 855            data center cooling failure
# 856            social engineering incident
# 857               slow network performance
# Name: Title, Length: 858, dtype: object

# %%
df['Description']=df['Description'].str.lower()
df['Description']
# Out:
# 0      users are experiencing unexpected errors in th...
# 1      an application upgrade introduces incompatibil...
# 2      database queries are timing out causing delays...
# 3                      the software license has expired.
# 4      an application freezes or hangs becoming unres...
#                              ...
# 853      data integrity issues detected in the database.
# 854    there is a power surge in the server room pote...
# 855    the cooling system in the data center has fail...
# 856    an employee falls victim to a social engineeri...
# 857    the network is experiencing slow performance c...
# Name: Description, Length: 858, dtype: object

# %%
def tokenize_text(text):
    tokens = nltk.word_tokenize(text)
    return tokens

# %%
# Tokenize the desired column and create a new column to store the tokens
df['tokenized_column'] = df['Description'].apply(tokenize_text)

# Print the tokenized column
print(df['tokenized_column'])
# Out:
# 0      [users, are, experiencing, unexpected, errors,...
# 1      [an, application, upgrade, introduces, incompa...
# 2      [database, queries, are, timing, out, causing,...
# 3              [the, software, license, has, expired, .]
# 4      [an, application, freezes, or, hangs, becoming...
#                              ...
# 853    [data, integrity, issues, detected, in, the, d...
# 854    [there, is, a, power, surge, in, the, server, ...
# 855    [the, cooling, system, in, the, data, center, ...
# 856    [an, employee, falls, victim, to, a, social, e...
# 857    [the, network, is, experiencing, slow, perform...
# Name: tokenized_column, Length: 858, dtype: object

# %%
df.head()
# Out:
#   Incident ID        Date      Time                                Title  \
# 0     IN31001  25/06/2023  08:55:00                      application bug
# 1      IN1001  28/06/2022  03:22:55  application upgrade incompatibility
# 2      IN2001  26/12/2020  05:50:32               database query timeout
# 3      IN3001  01/12/2023  14:10:00              software license expiry
# 4      IN4001  03/03/2021  13:35:32           application freeze or hang
#
#                                          Description           Category  \
# 0  users are experiencing unexpected errors in th...        Application
# 1  an application upgrade introduces incompatibil...  Application Issue
# 2  database queries are timing out causing delays...  Performance Issue
# 3                  the software license has expired.     Infrastructure
# 4  an application freezes or hangs becoming unres...        Performance
#
#   Priority    Status     Location    Department Duration Response Time  \
# 0   Medium      Open       Office  Applications        -             -
# 1     High  Resolved  Server Room  Applications       60            20
# 2   Medium  Resolved  Data Center            IT       45            15
# 3      Low  Resolved       Office            IT       10             5
# 4     High  Resolved       Office            IT       15             5
#
#   Resolution Time           Class  \
# 0               -     Application
# 1              40     Application
# 2              30     Performance
# 3               5  Infrastructure
# 4              10     Performance
#
#                                     tokenized_column
# 0  [users, are, experiencing, unexpected, errors,...
# 1  [an, application, upgrade, introduces, incompa...
# 2  [database, queries, are, timing, out, causing,...
# 3          [the, software, license, has, expired, .]
# 4  [an, application, freezes, or, hangs, becoming...

# %%
#stop word removal
stopwords=set(stopwords.words('english'))
def remove_stop(x):
    return ",".join([word for word in str(x).split() if word not in stopwords])
df['NewDescription']=df['tokenized_column'].apply(lambda x: remove_stop(x))
df['NewDescription']
# Out:
# 0      ['users',,'are',,'experiencing',,'unexpected',...
# 1      ['an',,'application',,'upgrade',,'introduces',...
# 2      ['database',,'queries',,'are',,'timing',,'out'...
# 3      ['the',,'software',,'license',,'has',,'expired...
# 4      ['an',,'application',,'freezes',,'or',,'hangs'...
#                              ...
# 853    ['data',,'integrity',,'issues',,'detected',,'i...
# 854    ['there',,'is',,'a',,'power',,'surge',,'in',,'...
# 855    ['the',,'cooling',,'system',,'in',,'the',,'dat...
# 856    ['an',,'employee',,'falls',,'victim',,'to',,'a...
# 857    ['the',,'network',,'is',,'experiencing',,'slow...
# Name: NewDescription, Length: 858, dtype: object

# %%
df.head()
# Out:
#   Incident ID        Date      Time                                Title  \
# 0     IN31001  25/06/2023  08:55:00                      application bug
# 1      IN1001  28/06/2022  03:22:55  application upgrade incompatibility
# 2      IN2001  26/12/2020  05:50:32               database query timeout
# 3      IN3001  01/12/2023  14:10:00              software license expiry
# 4      IN4001  03/03/2021  13:35:32           application freeze or hang
#
#                                          Description           Category  \
# 0  users are experiencing unexpected errors in th...        Application
# 1  an application upgrade introduces incompatibil...  Application Issue
# 2  database queries are timing out causing delays...  Performance Issue
# 3                  the software license has expired.     Infrastructure
# 4  an application freezes or hangs becoming unres...        Performance
#
#   Priority    Status     Location    Department Duration Response Time  \
# 0   Medium      Open       Office  Applications        -             -
# 1     High  Resolved  Server Room  Applications       60            20
# 2   Medium  Resolved  Data Center            IT       45            15
# 3      Low  Resolved       Office            IT       10             5
# 4     High  Resolved       Office            IT       15             5
#
#   Resolution Time           Class  \
# 0               -     Application
# 1              40     Application
# 2              30     Performance
# 3               5  Infrastructure
# 4              10     Performance
#
#                                     tokenized_column  \
# 0  [users, are, experiencing, unexpected, errors,...
# 1  [an, application, upgrade, introduces, incompa...
# 2  [database, queries, are, timing, out, causing,...
# 3          [the, software, license, has, expired, .]
# 4  [an, application, freezes, or, hangs, becoming...
#
#                                       NewDescription
# 0  ['users',,'are',,'experiencing',,'unexpected',...
# 1  ['an',,'application',,'upgrade',,'introduces',...
# 2  ['database',,'queries',,'are',,'timing',,'out'...
# 3  ['the',,'software',,'license',,'has',,'expired...
# 4  ['an',,'application',,'freezes',,'or',,'hangs'...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Aiswarya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#selecing features
X=df['NewDescription']
y=df['Class']

# %%
X.shape
# Out:
# (858,)

# %%
y.shape
# Out:
# (858,)

# %%
X.head()
# Out:
# 0    ['users',,'are',,'experiencing',,'unexpected',...
# 1    ['an',,'application',,'upgrade',,'introduces',...
# 2    ['database',,'queries',,'are',,'timing',,'out'...
# 3    ['the',,'software',,'license',,'has',,'expired...
# 4    ['an',,'application',,'freezes',,'or',,'hangs'...
# Name: NewDescription, dtype: object

# %%
vectorizer=TfidfVectorizer()
vectorizer
# Out:
# TfidfVectorizer()

# %%
column_name = 'NewDescription'
corpus = df[column_name]

# %%
tfidf_matrix = vectorizer.fit_transform(corpus)
tfidf_matrix
# Out:
# <858x1019 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9171 stored elements in Compressed Sparse Row format>

# %%
feature_names = vectorizer.get_feature_names()
feature_names
# Out:
# C:\Users\Aiswarya\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['ability',
#  'abnormal',
#  'abnormally',
#  'about',
#  'abruptly',
#  'acceptable',
#  'accepting',
#  'access',
#  'accessible',
#  'accessing',
#  'accidentally',
#  'account',
#  'accounts',
#  'accuracy',
#  'accurate',
#  'acls',
#  'acquisition',
#  'across',
#  'action',
#  'activated',
#  'activates',
#  'activities',
#  'activity',
#  'added',
#  'additional',
#  'address',
#  'addresses',
#  'adhere',
#  'adjusted',
#  'affected',
#  'affecting',
#  'affects',
#  'after',
#  'again',
#  'air',
#  'airflow',
#  'alarm',
#  'alarms',
#  'alert',
#  'align',
#  'alignment',
#  'all',
#  'allocation',
#  'allowed',
#  'allowing',
#  'amount',
#  'an',
#  'analyzing',
#  'and',
#  'anomalies',
#  'another',
#  'any',
#  'api',
#  'apis',
#  'appliance',
#  'application',
#  'applications',
#  'approval',
#  'archiving',
#  'are',
#  'area',
#  'areas',
#  'arise',
#  'array',
#  'as',
#  'assets',
#  'assign',
#  'assignment',
#  'assignments',
#  'attachment',
#  'attachments',
#  'attack',
#  'attacker',
#  'attacks',
#  'attempted',
#  'attempting',
#  'attempts',
#  'audio',
#  'audit',
#  'auditability',
#  'audits',
#  'authentication',
#  'authorization',
#  'availability',
#  'available',
#  'backup',
#  'backups',
#  'balancer',
#  'balancers',
#  'bandwidth',
#  'baseline',
#  'battery',
#  'be',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'behavior',
#  'being',
#  'better',
#  'between',
#  'beyond',
#  'bios',
#  'blacklisted',
#  'blocking',
#  'blocks',
#  'bottleneck',
#  'bottlenecks',
#  'bounced',
#  'breach',
#  'breaches',
#  'brute',
#  'bug',
#  'bugs',
#  'business',
#  'button',
#  'by',
#  'bypassing',
#  'cable',
#  'cables',
#  'cache',
#  'cameras',
#  'capabilities',
#  'capacity',
#  'card',
#  'cartridges',
#  'case',
#  'cause',
#  'causes',
#  'causing',
#  'cctv',
#  'center',
#  'certain',
#  'certificate',
#  'challenges',
#  'change',
#  'changes',
#  'check',
#  'checks',
#  'cleanup',
#  'codes',
#  'communicated',
#  'communication',
#  'company',
#  'compatibility',
#  'compatible',
#  'compilence',
#  'complete',
#  'completely',
#  'completeness',
#  'compliance',
#  'comply',
#  'component',
#  'components',
#  'compromise',
#  'compromised',
#  'compromising',
#  'computer',
#  'computers',
#  'concerns',
#  'concurrency',
#  'concurrent',
#  'conditioning',
#  'conditions',
#  'conducting',
#  'confidential',
#  'confidentiality',
#  'configuration',
#  'configurations',
#  'configured',
#  'configuring',
#  'conflict',
#  'conflicting',
#  'conflicts',
#  'congestion',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'connections',
#  'connectivity',
#  'consistency',
#  'consolidation',
#  'consuming',
#  'contains',
#  'contend',
#  'contention',
#  'control',
#  'controls',
#  'cooling',
#  'copies',
#  'correction',
#  'correctly',
#  'correctness',
#  'corrupted',
#  'corruption',
#  'cpu',
#  'crashed',
#  'crashes',
#  'creating',
#  'credentials',
#  'critical',
#  'cross',
#  'cursor',
#  'damage',
#  'damages',
#  'damaging',
#  'data',
#  'database',
#  'databases',
#  'ddos',
#  'deadlock',
#  'defaced',
#  'degradation',
#  'degraded',
#  'delay',
#  'delayed',
#  'delays',
#  'deleted',
#  'deletion',
#  'delivered',
#  'delivery',
#  'demanding',
#  'denial',
#  'denied',
#  'department',
#  'dependencies',
#  'deployment',
#  'design',
#  'desired',
#  'detect',
#  'detected',
#  'detecting',
#  'detection',
#  'detects',
#  'device',
#  'devices',
#  'dhcp',
#  'different',
#  'difficult',
#  'difficulties',
#  'disaster',
#  'disclosure',
#  'disconnected',
#  'discovered',
#  'discrepancies',
#  'disk',
#  'disks',
#  'display',
#  'displaying',
#  'displays',
#  'disposal',
#  'disrupted',
#  'disrupting',
#  'disruption',
#  'disruptions',
#  'distorted',
#  'distribute',
#  'distributed',
#  'distribution',
#  'disturbances',
#  'dns',
#  'documenting',
#  'documents',
#  'domain',
#  'down',
#  'download',
#  'downtime',
#  'drift',
#  'driver',
#  'drivers',
#  'drives',
#  'dropouts',
#  'drops',
#  'due',
#  'duplication',
#  'durations',
#  'during',
#  'easily',
#  'elements',
#  'elevated',
#  'email',
#  'emails',
#  'emergency',
#  'employee',
#  'employees',
#  'enabling',
#  'encounter',
#  'encountered',
#  'encountering',
#  'encounters',
#  'encryption',
#  'engineering',
#  'enhance',
#  'enhancement',
#  'ensure',
#  'entire',
#  'entries',
#  'entry',
#  'environmental',
#  'equipment',
#  'error',
#  'errors',
#  'escalate',
#  'essential',
#  'establish',
#  'establishing',
#  'evacuation',
#  'evenly',
#  'exceed',
#  'exceeded',
#  'exceeds',
#  'excessive',
#  'exchange',
#  'execute',
#  'execution',
#  'exfiltrate',
#  'exfiltration',
#  'exhausted',
#  'exhaustion',
#  'exhausts',
#  'exhibits',
#  'existing',
#  'expected',
#  'experience',
#  'experienced',
#  'experiences',
#  'experiencing',
#  'expire',
#  'expired',
#  'expires',
#  'exploited',
#  'export',
#  'exports',
#  'exposing',
#  'extended',
#  'external',
#  'facilitate',
#  'fail',
#  'failed',
#  'failover',
#  'fails',
#  'failure',
#  'failures',
#  'falls',
#  'fan',
#  'fans',
#  'feature',
#  'features',
#  'feeding',
#  'file',
#  'files',
#  'filter',
#  'filtered',
#  'filtering',
#  'fire',
#  'firewall',
#  'firmware',
#  'fix',
#  'fixes',
#  'flapping',
#  'flawed',
#  'flickering',
#  'flooded',
#  'flow',
#  'for',
#  'force',
#  'found',
#  'fragmented',
#  'freezes',
#  'frequent',
#  'from',
#  'full',
#  'functionality',
#  'functioning',
#  'further',
#  'gain',
#  'gained',
#  'gains',
#  'gaps',
#  'generator',
#  'get',
#  'gets',
#  'getting',
#  'glitch',
#  'go',
#  'governance',
#  'gradual',
#  'gradually',
#  'guessable',
#  'handle',
#  'handling',
#  'hangs',
#  'hard',
#  'hardware',
#  'has',
#  'have',
#  'having',
#  'hazard',
#  'headphone',
#  'headphones',
#  'heat',
#  'heavy',
#  'high',
#  'hindering',
#  'historical',
#  'host',
#  'hosted',
#  'hosting',
#  'hot',
#  'hr',
#  'humidity',
#  'hvac',
#  'identified',
#  'identify',
#  'identifying',
#  'images',
#  'immediate',
#  'immediately',
#  'impacting',
#  'implementing',
#  'import',
#  'important',
#  'imposed',
#  'improper',
#  'improperly',
#  'improve',
#  'improved',
#  'improvements',
#  'in',
#  'inability',
#  'inaccessible',
#  'inaccuracies',
#  'inactivity',
#  'inadequate',
#  'incident',
#  'incoming',
#  'incompatibility',
#  'incompatible',
#  'incomplete',
#  'incompletely',
#  'inconsistencies',
#  'inconsistency',
#  'inconsistent',
#  'incorrect',
#  'incorrectly',
#  'increased',
#  'increases',
#  'increasing',
#  'indefinitely',
#  'indexes',
#  'indexing',
#  'indicating',
#  'individuals',
#  'inefficient',
#  'infected',
#  'information',
#  'infrastructure',
#  'ingress',
#  'injection',
#  'ink',
#  'input',
#  'insider',
#  'instability',
#  'install',
#  'installation',
#  'installed',
#  'installing',
#  'insufficient',
#  'integrate',
#  'integrating',
#  'integration',
#  'integrations',
#  'integrity',
#  'intent',
#  'interacting',
#  'interface',
#  'interference',
#  'intermittent',
#  'intermittently',
#  'internal',
#  'internet',
#  'interruption',
#  'interruptions',
#  'intervention',
#  'into',
#  'introduce',
#  'introduced',
#  'introduces',
#  'intrusion',
#  'invalid',
#  'investigation',
#  'investigations',
#  'involving',
#  'ip',
#  'is',
#  'isolate',
#  'isolated',
#  'issue',
#  'issues',
#  'it',
#  'its',
#  'jack',
#  'jam',
#  'jammed',
#  'jams',
#  'key',
#  'keyboard',
#  'keys',
#  'known',
#  'lag',
#  'language',
#  'laptop',
#  'large',
#  'latency',
#  'latest',
#  'leading',
#  'leads',
#  'leak',
#  'leakage',
#  'lease',
#  'leases',
#  'leaving',
#  'legitimate',
#  'level',
#  'levels',
#  'license',
#  'licenses',
#  'limit',
#  'limiting',
#  'limits',
#  'link',
#  'links',
#  'lists',
#  'load',
#  'local',
#  'localization',
#  'location',
#  'locked',
#  'locking',
#  'locks',
#  'log',
#  'logging',
#  'login',
#  'logs',
#  'long',
#  'longer',
#  'lookup',
#  'loop',
#  'loops',
#  'lose',
#  'loses',
#  'loss',
#  'lost',
#  'low',
#  'mac',
#  'machines',
#  'made',
#  'maintenance',
#  'makes',
#  'making',
#  'malfunction',
#  'malfunctioned',
#  'malfunctions',
#  'malicious',
#  'malware',
#  'managing',
#  'manipulate',
#  'manipulation',
#  'manual',
#  'marked',
#  'measures',
#  'mechanisms',
#  'medium',
#  'memory',
#  'message',
#  'messages',
#  'migrate',
#  'migration',
#  'minimal',
#  'misclassified',
#  'misclassifies',
#  'misconfiguration',
#  'misconfigurations',
#  'misconfigured',
#  'mismatch',
#  'missing',
#  'mistakenly',
#  'mitigation',
#  'modifications',
#  'modify',
#  'modifying',
#  'modules',
#  'monitor',
#  'monitoring',
#  'more',
#  'mouse',
#  'moving',
#  'multiple',
#  'name',
#  'necessary',
#  'need',
#  'needed',
#  'needs',
#  'network',
#  'new',
#  'newly',
#  'no',
#  'not',
#  'notifications',
#  'occasional',
#  'occurred',
#  'occurs',
#  'of',
#  'office',
#  'offline',
#  'often',
#  'old',
#  'on',
#  'one',
#  'online',
#  'operating',
#  'operation',
#  'operational',
#  'operations',
#  'optimal',
#  'optimization',
#  'optimize',
#  'optimized',
#  'optimizing',
#  'or',
#  'organization',
#  'organizing',
#  'other',
#  'out',
#  'outage',
#  'outages',
#  'outgoing',
#  'outputs',
#  'over',
#  'overall',
#  'overheating',
#  'overheats',
#  'overloaded',
#  'oversight',
#  'packet',
#  'packets',
#  'paper',
#  'partial',
#  'partitioned',
#  'party',
#  'password',
#  'patch',
#  'patches',
#  'patching',
#  'patterns',
#  'perform',
#  'performance',
#  'performing',
#  'period',
#  'permanent',
#  'permission',
#  'permissions',
#  'personal',
#  'phishing',
#  'physical',
#  'placed',
#  'planned',
#  'plugins',
#  'point',
#  'poisoned',
#  'policies',
#  'policy',
#  'pool',
#  'poor',
#  'port',
#  'posing',
#  'potential',
#  'potentially',
#  'power',
#  'practices',
#  'premature',
#  'prematurely',
#  'presence',
#  'press',
#  'pressed',
#  'presses',
#  'prevent',
#  'preventing',
#  'previous',
#  'print',
#  'printer',
#  'printing',
#  'prioritize',
#  'privacy',
#  'privileges',
#  'proactively',
#  'problem',
#  'problems',
#  'process',
#  'processed',
#  'processes',
#  'processing',
#  'producing',
#  'productivity',
#  'proper',
#  'properly',
#  'protection',
#  'protocol',
#  'provider',
#  'providing',
#  'purposes',
#  'qos',
#  'quality',
#  'queries',
#  'query',
#  'quickly',
#  'rack',
#  'racks',
#  'raid',
#  'raises',
#  'raising',
#  'ransom',
#  'ransomware',
#  'rates',
#  'reached',
#  'reaches',
#  'read',
#  'rebackup',
#  'rebuilt',
#  'receive',
#  'received',
#  'receiving',
#  'recent',
#  'recipients',
#  'reconciliation',
#  'reconfiguration',
#  'recording',
#  'recovering',
#  'recovery',
#  'reduce',
#  'reduced',
#  'redundancy',
#  'reference',
#  'registering',
#  'regression',
#  'relay',
#  'reliability',
#  'remediation',
#  'remote',
#  'rendering',
#  'renewal',
#  'repeatedly',
#  'replacement',
#  'replicas',
#  'replication',
#  'reported',
#  'reports',
#  'request',
#  'requests',
#  'require',
#  'required',
#  'requirements',
#  'requires',
#  'requiring',
#  'resets',
#  'resolution',
#  'resolve',
#  'resolving',
#  'resource',
#  'resources',
#  'responding',
#  'responds',
#  'response',
#  'restart',
#  'restoration',
#  'restrict',
#  'restricted',
#  'restriction',
#  'restrictions',
#  'resulting',
#  'results',
#  'retention',
#  'retransmissions',
#  'retrieval',
#  'retrieving',
#  'revealing',
#  'review',
#  'reviewing',
#  'rises',
#  'risk',
#  'risking',
#  'rollback',
#  'room',
#  'router',
#  'routine',
#  'routing',
#  'rule',
#  'rules',
#  'run',
#  'running',
#  'safeguard',
#  'saturated',
#  'scalability',
#  'scanner',
#  'scheduled',
#  'schema',
#  'screen',
#  'scripting',
#  'scroll',
#  'search',
#  'security',
#  'segment',
#  'segmentation',
#  'segments',
#  'send',
#  'sending',
#  'sensitive',
#  'sensor',
#  'server',
#  'servers',
#  'service',
#  'services',
#  'session',
#  'sessions',
#  'setting',
#  'settings',
#  'setup',
#  'several',
#  'shared',
#  'shutdown',
#  'shutting',
#  'signal',
#  'signals',
#  'significant',
#  'significantly',
#  'site',
#  'situation',
#  'size',
#  'slow',
#  'slowdowns',
#  'slower',
#  'slowing',
#  'slowly',
#  'smoke',
#  'smtp',
#  'snmp',
#  'social',
#  'software',
#  'some',
#  'source',
#  'sources',
#  'space',
#  'spam',
#  'spanning',
#  'speakers',
#  'specific',
#  'specified',
#  'speeds',
#  'spoofing',
#  'sql',
#  'standards',
#  'start',
#  'startup',
#  'state',
#  'status',
#  'sticking',
#  'stop',
#  'stopped',
#  'stops',
#  'storage',
#  'stored',
#  'subnets',
#  'suboptimal',
#  'successful',
#  'successfully',
#  'sudden',
#  'supply',
#  'support',
#  'suppression',
#  'surge',
#  'surveillance',
#  'suspicious',
#  'switch',
#  'switches',
#  'synchronization',
#  'system',
#  'systems',
#  'table',
#  'tables',
#  'tagging',
#  'takes',
#  'taking',
#  'temperature',
#  'temperatures',
#  'temporary',
#  'term',
#  'terminates',
#  'termination',
#  'testing',
#  'text',
#  'than',
#  'that',
#  'the',
#  'theft',
#  'their',
#  'them',
#  'there',
#  'third',
#  'threat',
#  'threshold',
#  'throughput',
#  'time',
#  'timeout',
#  'timeouts',
#  'times',
#  'timing',
#  'to',
#  'toner',
#  'too',
#  'tools',
#  'traceability',
#  'track',
#  'traffic',
#  'transaction',
#  'transactions',
#  'transfer',
#  'translations',
#  'transmission',
#  'tree',
#  'triggered',
#  'triggering',
#  'trouble',
#  'troubleshoot',
#  'troubleshooting',
#  'trunking',
#  'trying',
#  'tuning',
#  'tunnel',
#  'turning',
#  'unable',
#  'unauthorized',
#  'unavailability',
#  'unavailable',
#  'under',
#  'uneven',
#  'unexpected',
#  'unexpectedly',
#  'unintended',
#  'unintentionally',
#  'uninterruptible',
#  'unit',
#  'unknown',
#  'unpatched',
#  'unreachable',
#  'unrecoverability',
#  'unresponsive',
#  'unsecured',
#  'unstable',
#  'unusable',
#  'up',
#  'update',
#  'updated',
#  'updates',
#  'updating',
#  'upgrade',
#  'upgraded',
#  'upgrades',
#  'upgrading',
#  'upload',
#  'uploading',
#  'uploads',
#  'upon',
#  'ups',
#  'usability',
#  'usage',
#  'used',
#  'user',
#  'users',
#  'using',
#  'usual',
#  'utilization',
#  'validation',
#  'verification',
#  'verifying',
#  'version',
#  'versions',
#  'very',
#  'victim',
#  'violates',
#  'violation',
#  'virtual',
#  'virtualization',
#  'virus',
#  'visual',
#  'vlan',
#  'vlans',
#  'volume',
#  'vpn',
#  'vulnerabilities',
#  ...]

# %%
for i in range(len(corpus)):
    print("word{}: ".format(i+1))
    for j, feature in enumerate(feature_names):
        tfidf_value = tfidf_matrix[i, j]
        if tfidf_value > 0:
            print("   {}: {}".format(feature, tfidf_value))
# Out:
# word1:
#    application: 0.23949173983628053
#    are: 0.38220267703526284
#    errors: 0.4239429503873512
#    experiencing: 0.4353929822653639
#    in: 0.20720251942310108
#    the: 0.14074605761133524
#    unexpected: 0.48499540934519286
#    employee: 0.2957086501332251
#    engineering: 0.37572396873455044
#    falls: 0.3269782758603042
#    information: 0.27614608273982244
#    revealing: 0.37572396873455044
#    sensitive: 0.25322888954682293
#    social: 0.37572396873455044
#    to: 0.11596409710805923
#    victim: 0.33884927557780975
# word858:
#    causing: 0.23743687377411968
#    data: 0.2210071780252195
#    delays: 0.38119645866024393
#    experiencing: 0.3702397557086318
#    in: 0.17619624867234507
#    is: 0.1816963980922052
#    network: 0.22581824424970345
#    performance: 0.29211260956280977
#    slow: 0.37285306535983387
#    the: 0.11968448759978828
#    transfer: 0.5085913893133205

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix,y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (686, 1019)

# %%
y_train.shape
# Out:
# (686,)

# %%
X_test.shape
# Out:
# (172, 1019)

# %%
svm_model = SVC(kernel='linear')

# Train the SVM model
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svm_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8488372093023255

# %%
def predict_class(description, vectorizer, model):
    # Convert the description into a TF-IDF matrix using the provided vectorizer
    tfidf = vectorizer.transform([description])

    # Predict the class for the description using the provided model
    prediction = model.predict(tfidf)

    return prediction

# %%
new_description = "A server is misconfigured resulting in operational issues or vulnerabilities."


# Concatenate the description and title
new_text = new_description 

# Predict the class for the new data
predicted_class = predict_class(new_description, vectorizer, svm_model)

# Print the predicted class
print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: ['Configuration']

# %%
from sklearn.metrics import precision_score,recall_score,f1_score,accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision:", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall:", recall)
# Calculate F1-score
f1 = f1_score(y_test, y_pred, average='weighted')
print("F1-score:", f1)
# Out:
# Accuracy: 0.8488372093023255
# Precision: 0.8547307585825028
# Recall: 0.8488372093023255
# F1-score: 0.8478649993634794

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, y, test_size=0.2, random_state=42)

# Initialize the Random Forest classifier
rf_model = RandomForestClassifier()

# Train the Random Forest model
rf_model.fit(X_train, y_train)

# Predict the labels for the test set
y_pred = rf_model.predict(X_test)

# %%
def predict_class(description, vectorizer, model):
    # Convert the description into a TF-IDF matrix using the provided vectorizer
    tfidf = vectorizer.transform([description])

    # Predict the class for the description using the provided model
    prediction = model.predict(tfidf)

    return prediction

# %%
new_description = "Internet connection dropping frequently"


# Concatenate the description and title
new_text = new_description 

# Predict the class for the new data
predicted_class = predict_class(new_description, vectorizer, svm_model)

# Print the predicted class
print("Predicted Class:", predicted_class)
# Out:
# Predicted Class: ['Network']

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
precision = precision_score(y_test, y_pred, average='weighted')
print("Precision:", precision)
recall = recall_score(y_test, y_pred, average='weighted')
print("Recall:", recall)
# Calculate F1-score
f1 = f1_score(y_test, y_pred, average='weighted')
print("F1-score:", f1)
# Out:
# Accuracy: 0.8197674418604651
# Precision: 0.8224986966061718
# Recall: 0.8197674418604651
# F1-score: 0.8192178607280113

# %%
col=['NewDescription']
sp=df[col]
sp
# Out:
#                                         NewDescription
# 0    ['users',,'are',,'experiencing',,'unexpected',...
# 1    ['an',,'application',,'upgrade',,'introduces',...
# 2    ['database',,'queries',,'are',,'timing',,'out'...
# 3    ['the',,'software',,'license',,'has',,'expired...
# 4    ['an',,'application',,'freezes',,'or',,'hangs'...
# ..                                                 ...
# 853  ['data',,'integrity',,'issues',,'detected',,'i...
# 854  ['there',,'is',,'a',,'power',,'surge',,'in',,'...
# 855  ['the',,'cooling',,'system',,'in',,'the',,'dat...
# 856  ['an',,'employee',,'falls',,'victim',,'to',,'a...
# 857  ['the',,'network',,'is',,'experiencing',,'slow...
#
# [858 rows x 1 columns]
